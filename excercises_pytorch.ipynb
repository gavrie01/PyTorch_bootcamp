# %%
import torch
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#scalar
scalar = torch.tensor(7)
scalar
# Out:
# tensor(7)

# %%
scalar.item()
# Out:
# 7

# %%
vector = torch.tensor([7,7])
vector
# Out:
# tensor([7, 7])

# %%
#2 []
vector.shape
# Out:
# torch.Size([2])

# %%
#MATRIX
MATRIX = torch.tensor([[7,8], [6,9]])
MATRIX.ndim
# Out:
# 2

# %%
MATRIX[1]
# Out:
# tensor([6, 9])

# %%
#TENSOR
TENSOR = torch.tensor([[[1,2,3], [5,9,16],[7,9,3]]])
TENSOR
# Out:
# tensor([[[ 1,  2,  3],
#          [ 5,  9, 16],
#          [ 7,  9,  3]]])

# %%
TENSOR.ndim
# Out:
# 3

# %%
TENSOR[0]
# Out:
# tensor([[ 1,  2,  3],
#         [ 5,  9, 16],
#         [ 7,  9,  3]])

# %%
#random tensors - the way many nn learn is they start w tensors full of random numbers and adjust random numbers to better represent data
random_tensor = torch.rand(3,4)
random_tensor
# Out:
# tensor([[0.2060, 0.3209, 0.0112, 0.5775],
#         [0.7552, 0.8102, 0.5454, 0.3009],
#         [0.4691, 0.8657, 0.5386, 0.6553]])

# %%
random_image_size_tensor = torch.rand(size=(224,224,3))# height, width, color channel (red, green, blue)
